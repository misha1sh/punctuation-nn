# %%
import imports
import importlib
importlib.reload(imports)
from imports import *

# https://pymorphy2.readthedocs.io/en/stable/user/grammemes.html
# http://opencorpora.org/dict.php?act=gram
# https://github.com/pymorphy2/pymorphy2/blob/92d546f042ff14601376d3646242908d5ab786c1/pymorphy2/tagset.py#L130
feature_tags_array = [
    OpencorporaTag.PARTS_OF_SPEECH, # часть речи
    OpencorporaTag.GENDERS, # род
    OpencorporaTag.NUMBERS, # число
    OpencorporaTag.CASES, # падеж
    OpencorporaTag.ASPECTS, # соверш / несоверш
    OpencorporaTag.TRANSITIVITY, # перех / непереходный
    OpencorporaTag.PERSONS, # лицо
    OpencorporaTag.TENSES, # время
    OpencorporaTag.MOODS, # наклонение
    OpencorporaTag.VOICES, # залог
    #INVOLVEMENT
    ['Prnt'], # вводные слова
    ['Apro'], # местоимение
    ['NUMB'], # число вида 1234
    ['LATIN'], # текст на английском
    ['UNKN'], # неизвестный токен
    ['PUNCT_DASH', 'PUNCT_DOT', 'PUNCT_COMMA', 'PUNCT_QUOTE',
     'PUNCT_LEFT_PARENTHESIS', 'PUNCT_RIGHT_PARENTHESIS' ], # "()
    ['CAPITALIZED'], # начинается с заглавной буквы
    ['Fixd', 'Abbr'] # неизменяемое, сокращение
]

CUT_NAVEC_TAGS_ARRAY = [
    #'NOUN', #'ADJF'
]

params = build_params({
    "VARIANTS_CNT": 1, ###!!!!!!! WRITE TO 50 megabytes instead of 10
    "TARGET_CLASSES_COUNT": 3,
    "INPUT_WORDS_CNT": 32,
    "feature_tags_array": [
        ['NUMB'], # число вида 1234
        ['LATIN'], # текст на английском
        ['UNKN'], # неизвестный токен
        ['PUNCT_DASH', 'PUNCT_DOT', 'PUNCT_COMMA', 'PUNCT_QUOTE',
        'PUNCT_LEFT_PARENTHESIS', 'PUNCT_RIGHT_PARENTHESIS' ], # "()
        ['CAPITALIZED']
    ],  ###!!!!!!! WRITE TO 50 megabytes instead of 10
    
    "PUNCTUATION_TARGET": {
        "$empty": NO_PUNCT,
        ",": 1,
        ".": 2,
        "!": 2,
        "?": 2,
    },
    "USE_NAVEC": True,
    'CUT_NAVEC_TAGS_SET': set(CUT_NAVEC_TAGS_ARRAY),
    "RETAIN_LEFT_PUNCT": True,
    'type': 'lenta',
    'NON_PUNCT_PROB': 0.5,

    'INFECTED_TEXT_PROB': 0.5,
    'INFECT_TYPE_PROBS': {
        'REPLACE_UNDEF': 0.1,
        'INCORRECT_PUNCT_RANDOM_PLACE': 0.1,
        'INCORRECT_PUNCT_CENTER': 0.2,
        'CORRECT_PUNCT_CENTER': 0.3,
        'CORRECT_PUNCT_RIGHT': 0.3,
    }
})
# print("NON_PUNCT_PROB': 0.3,\n" * 10)
# print("INFECTED_TEXT_PROB': 0\n" * 10)

# %%
Брать 10% каждого чанка и при запуске проверять до / после и смотреть, было ли улучшение

# %%
random.seed(42)
np.random.seed(42)

import dataset_builder
importlib.reload(dataset_builder)

dataset_builder.create_dataset_for_text("Привет, тест. это тест. Тест.", params)[2:4]
# Out:
# ([['PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'Привет',
#    ' #,# ',
#    '.',
#    'тест',
#    'это',
#    'тест',
#    'Тест',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD'],
#   ['PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'Привет',
#    ',',
#    'тест',
#    ' #.# ',
#    'это',
#    'тест',
#    '.',
#    'Тест',
#    '.',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD'],
#   ['PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'Привет',
#    ',',
#    'тест',
#    '.',
#    'это',
#    'тест',
#    ' #.# ',
#    ',',
#    'Тест',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD'],
#   ['PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'Привет',
#    ',',
#    'тест',
#    '.',
#    'это',
#    'тест',
#    '.',
#    'Тест',
#    ' #.# ',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD',
#    'PAD']],
#  tensor([3, 5, 3, 0], dtype=torch.uint8))

# %%
server = run_server_if_not_running()
server_install_packages(server)

# server.rpc_simple(dataset_builder.get_word_features, 'кошка', params).shape
# server.rpc_simple(dataset_builder.create_dataset, ['а, б'], params, False)[0].shape

# %%
params["train_test_split"] = 0.9
# lenta -- 50

params["chunk_size"] = 10 # 3000 # 300000
params["batch_size"] = 20000
params["max_parallel"] = 3
params["type"] = "lenta"

params["max_last_read_queue_size"] = 1

class AutoWriter:
    def __init__(self, name, storage) -> None:
        self.name = name
        self.storage = storage
        self.x = None

    def write_splitted(self, x, cnt, cnt_per_elem):
        if self.x == None:
            self.x = x
        elif isinstance(x, torch.Tensor):
            self.x = torch.cat((self.x, x))
        else:
            assert isinstance(x, list)
            self.x += x
        
        llen = self.x.shape[0] if isinstance(self.x, torch.Tensor) else len(self.x)
        for i in range(0, llen, cnt_per_elem):
            if i + cnt_per_elem < llen:
                vv = self.x[i: i + cnt_per_elem]
                self.storage.store(self.name, cnt, 
                                   vv.clone() if isinstance(self.x, torch.Tensor)
                                   else vv)
                cnt += 1
            else:
                self.x = self.x[i:]
                break

        return cnt
        
    def write(self, x, cnt):
        cnt_per_elem = math.floor(x.shape[0] / 
                                    size_of_tensor(x) * 
                                    (10 * 1024 * 1024))
        cnt = self.write_splitted(x, cnt, cnt_per_elem)
        return cnt_per_elem, cnt

class AsyncDatasetWriter:
    def __init__(self, rpc_server):
        self.storage = Storage("cache2/storage_no_morph")
        self.storage.clear()
        self.chunks_count = 0

        self.storage.write_meta("chunks_count", 0)
        self.storage.write_meta("params", params)

        self.parallel_count = threading.Semaphore(params["max_parallel"])
        self.write_queue = queue.Queue()
        # self.thread_write = threading.Thread(target=asyncio.run, args=(self.write_task(),))
        
        self.device = torch.device('cuda:0')

        self.chunks_iter = None
        self.rpc_server = rpc_server

        self.x_a = AutoWriter("x", self.storage)
        self.y_a = AutoWriter("y", self.storage)
        self.text_res_a = AutoWriter("text_res", self.storage)
        self.is_infected_a = AutoWriter("is_infected", self.storage)
        
        self.thread_write = threading.Thread(target=self.write_task)
        self.thread_write.start()
        
        
    def chunk_loaded_callback(self, future):
        print("chunk_loaded_callback")
        self.write_queue.put(future)
  

    def test_loaded_callback(self, future):
        print("got test")
        x, y, text_res, is_infected = future.get_result()
        print("writing test started cnt=", x.shape[0], "size=", size_of_tensor(x) / 1024 / 1024, "MB")
        self.storage.write_meta("x_test", x)
        self.storage.write_meta("y_test", y)
        self.storage.write_meta("text_res_test", text_res)
        self.storage.write_meta("is_infected_test", is_infected)
        print("writing test finsihed")

    def has_free_space(self):
        free_space_gb = shutil.disk_usage(self.storage.path).free / 1024 / 1024 / 1024
        if free_space_gb < 5:
            print(f"Out of disk space. Remainging {free_space_gb} GB")
            return False
        return True
        



    def write(self, future, i):
        if not self.has_free_space(): return
        # if future.exception() is not None:
        #     future.
            # absprint("ERROR: ", future.exception(), "\n", 
                    # "\n".join(traceback.format_tb(future.traceback())  ))
            # raise future.exception()
        x, y, text_res, is_infected = future.get_result()
        print("writing started", size_of_tensor(x) / 1024 / 1024, "MB")
        cnt_per_elem, new_i = self.x_a.write(x, i)
        assert self.y_a.write_splitted(y, i, cnt_per_elem) == new_i
        assert self.text_res_a.write_splitted(text_res, i, cnt_per_elem) == new_i
        assert self.is_infected_a.write_splitted(is_infected, i, cnt_per_elem) == new_i
        self.parallel_count.release()
        self.write_queue.task_done()
        print("writing finished")
        self.chunks_count += (new_i - i)
        print("chunks_count", self.chunks_count)
        self.storage.write_meta("chunks_count", self.chunks_count)
        return new_i

    def write_task(self):        
        try:
            print("write_task started")
            keep_running = True        
            def handle_executor_done_callback(future):
                nonlocal keep_running
                try:
                    future.result()
                except Exception as e:
                    print("ERROR", "writer thread failed:\n", type(e).__name__, e)
                    print("\n".join(traceback.format_tb(e.__traceback__)))
                    keep_running = False

            chunk_number = 0
            while keep_running:
                chunk_number = self.write(self.write_queue.get(), chunk_number)

            # with concurrent.futures.ThreadPoolExecutor(params["max_parallel"], "WRITER") as executor:
            #     chunk_number = 0
            #     while keep_running:
            #         if not self.has_free_space(): return
            #         future = executor.submit(self.write, self.write_queue.get(), chunk_number)
            #         future.add_done_callback(handle_executor_done_callback)
            #         chunk_number += 1

        except Exception as e:
            print("ERROR", "writer thread failed:\n", type(e).__name__, e)
            print("\n".join(traceback.format_tb(e.__traceback__)))
    
    def load_dataset(self, stream):
        # lenta -- 200
        test_chunk = stream.get(50)
        future = self.rpc_server.rpc_async(dataset_builder.create_dataset, test_chunk, params, False)
        future.set_callback(self.test_loaded_callback)
        
        # with concurrent.futures.ThreadPoolExecutor(max_workers=params["max_parallel"]) as executor:
        for chunk in stream.group(params["chunk_size"]):
            if not self.thread_write.is_alive(): return
            self.parallel_count.acquire()

            print("submit task")
            future = self.rpc_server.rpc_async(dataset_builder.create_dataset, chunk, params, False)
            future.set_callback(self.chunk_loaded_callback)
            future = None
        
        
from dataset_lib import get_lenta_records, get_writers_multi_stream
server = run_server_if_not_running()
server_install_packages(server)
# stream = Stream(get_lenta_records()).skip(5000).limit(200_000).map(lambda record: record.text)
stream = get_writers_multi_stream().limit(200_000)
writer = AsyncDatasetWriter(server)
writer.load_dataset(stream)
print("DONE")
# Out:
# Server is listening on 0.0.0.0:65231
# Connected by ('51.250.1.213', 50428)
# write_task started
# submit task
# submit task
# submit task
# got test
# writing test started cnt= 12913 size= 245.11370849609375 MB
# writing test finsihed
# chunk_loaded_callback
# writing started 57.49627685546875 MB
# writing finished
# chunks_count 5
# submit task
# chunk_loaded_callback
# writing started 32.0794677734375 MB
# writing finished
# chunks_count 8
# submit task
# chunk_loaded_callback
# writing started 27.713623046875 MB
# writing finished
# chunks_count 11
# submit task
# chunk_loaded_callback
# writing started 31.33917236328125 MB
# writing finished
# chunks_count 14
# submit task
# chunk_loaded_callback
# writing started 40.621337890625 MB
# writing finished
# chunks_count 18
# submit task
# chunk_loaded_callback
# writing started 33.04754638671875 MB
# writing finished
# chunks_count 22
# submit task
# chunk_loaded_callback
# writing started 35.85687255859375 MB
# writing finished
# chunks_count 25
# submit task
# chunk_loaded_callback
# writing started 24.61956787109375 MB
# writing finished
# chunks_count 28
# submit task
# chunk_loaded_callback
# writing started 21.69635009765625 MB
# writing finished
# chunks_count 30
# submit task
# chunk_loaded_callback
# writing started 40.1278076171875 MB
# writing finished
# chunks_count 34
# submit task
# chunk_loaded_callback
# writing started 31.60491943359375 MB
# writing finished
# chunks_count 37
# submit task
# chunk_loaded_callback
# writing started 61.44451904296875 MB
# writing finishedsubmit task
#
# chunks_count 43
# chunk_loaded_callback
# writing started 21.5255126953125 MB
# writing finished
# chunks_count 45
# submit task
# chunk_loaded_callback
# writing started 19.9310302734375 MB
# writing finished
# chunks_count 47
# submit task
# chunk_loaded_callback
# writing started 37.75506591796875 MB
# writing finished
# chunks_count 51
# submit task
# chunk_loaded_callback
# writing started 66.83538818359375 MB
# writing finishedsubmit task
#
# chunks_count 58
# chunk_loaded_callback
# writing started 29.32708740234375 MB
# writing finished
# chunks_count 61
# submit task
# chunk_loaded_callback
# writing started 22.474609375 MB
# writing finished
# chunks_count 63
# submit task
# chunk_loaded_callback
# writing started 60.969970703125 MB
# writing finishedsubmit task
#
# chunks_count 69
# chunk_loaded_callback
# writing started 13.53411865234375 MB
# writing finished
# chunks_count 71
# submit task
# chunk_loaded_callback
# writing started 107.15301513671875 MB
# writing finishedsubmit task
#
# chunks_count 81
# chunk_loaded_callback
# writing started 23.06304931640625 MB
# writing finished
# chunks_count 84
# submit task
# chunk_loaded_callback
# writing started 17.02679443359375 MB
# writing finished
# chunks_count 85
# submit task
# chunk_loaded_callback
# writing started 107.41876220703125 MB
# writing finished
# chunks_count 96
# submit task
# chunk_loaded_callback
# writing started 32.78179931640625 MB
# writing finished
# chunks_count 99
# submit task
# chunk_loaded_callback
# writing started 9.69976806640625 MB
# writing finished
# chunks_count 100
# submit task
# chunk_loaded_callback
# writing started 37.48931884765625 MB
# writing finished
# chunks_count 104
# submit task
# chunk_loaded_callback
# writing started 35.5341796875 MB
# writing finished
# chunks_count 108
# submit task
# chunk_loaded_callback
# writing started 19.11480712890625 MB
# writing finished
# chunks_count 110
# submit task
# chunk_loaded_callback
# writing started 61.19775390625 MB
# writing finishedsubmit task
#
# chunks_count 116
# chunk_loaded_callback
# writing started 37.280517578125 MB
# writing finished
# chunks_count 119
# submit task
# chunk_loaded_callback
# writing started 137.656982421875 MB
# writing finished
# chunks_count 133
# submit task
# chunk_loaded_callback
# writing started 42.00701904296875 MB
# writing finished
# chunks_count 137
# submit task
# chunk_loaded_callback
# writing started 24.14501953125 MB
# writing finished
# chunks_count 140
# submit task
# chunk_loaded_callback
# writing started 52.8836669921875 MB
# writing finished
# chunks_count 145
# submit task
# chunk_loaded_callback
# writing started 29.61181640625 MB
# writing finished
# chunks_count 148
# submit task
# chunk_loaded_callback
# writing started 73.1943359375 MB
# writing finishedsubmit task
#
# chunks_count 155
# chunk_loaded_callback
# writing started 18.81109619140625 MB
# writing finished
# chunks_count 157
# submit task
# chunk_loaded_callback
# writing started 19.513427734375 MB
# writing finished
# chunks_count 159
# submit task
# chunk_loaded_callback
# writing started 48.74560546875 MB
# writing finished
# chunks_count 164
# submit task
# chunk_loaded_callback
# writing started 15.12860107421875 MB
# writing finished
# chunks_count 166
# submit task
# chunk_loaded_callback
# writing started 23.51861572265625 MB
# writing finished
# chunks_count 168
# submit task
# chunk_loaded_callback
# writing started 16.400390625 MB
# writing finished
# chunks_count 170
# submit task
# chunk_loaded_callback
# writing started 102.3126220703125 MB
# writing finishedsubmit task
#
# chunks_count 180
# chunk_loaded_callback
# writing started 23.10101318359375 MB
# writing finished
# chunks_count 182
# submit task
# chunk_loaded_callback
# writing started 27.73260498046875 MB
# writing finished
# chunks_count 185
# submit task
# chunk_loaded_callback
# writing started 80.103759765625 MB
# writing finishedsubmit task
#
# chunks_count 193
# chunk_loaded_callback
# writing started 46.56268310546875 MB
# writing finishedsubmit task
#
# chunks_count 198
# chunk_loaded_callback
# writing started 36.7110595703125 MB
# writing finished
# chunks_count 201
# submit task
# chunk_loaded_callback
# writing started 24.08807373046875 MB
# writing finished
# chunks_count 204
# submit task
# chunk_loaded_callback
# writing started 43.60150146484375 MB
# writing finished
# chunks_count 208
# submit task
# chunk_loaded_callback
# writing started 20.576416015625 MB
# writing finished
# chunks_count 210
# submit task
# chunk_loaded_callback
# writing started 28.8905029296875 MB
# writing finished
# chunks_count 213
# submit task
# chunk_loaded_callback
# writing started 10.326171875 MB
# writing finished
# chunks_count 214
# submit task
# chunk_loaded_callback
# writing started 39.9759521484375 MB
# writing finished
# chunks_count 218
# submit task
# chunk_loaded_callback
# writing started 65.9052734375 MB
# writing finishedsubmit task
#
# chunks_count 225
# chunk_loaded_callback
# writing started 8.21917724609375 MB
# writing finished
# chunks_count 226
# submit task
# chunk_loaded_callback
# writing started 44.70245361328125 MB
# writing finished
# chunks_count 230
# submit task
# chunk_loaded_callback
# writing started 53.51007080078125 MB
# writing finishedsubmit task
#
# chunks_count 235
# chunk_loaded_callback
# writing started 29.2701416015625 MB
# writing finished
# chunks_count 238
# submit task
# chunk_loaded_callback
# writing started 26.802490234375 MB
# writing finished
# chunks_count 241
# submit task
# chunk_loaded_callback
# writing started 43.22186279296875 MB
# writing finished
# chunks_count 245
# submit task
# chunk_loaded_callback
# writing started 19.95001220703125 MB
# writing finished
# chunks_count 247
# submit task
# chunk_loaded_callback
# writing started 47.05621337890625 MB
# writing finishedsubmit task
#
# chunks_count 252
# chunk_loaded_callback
# writing started 42.1778564453125 MB
# writing finished
# chunks_count 256
# submit task
# chunk_loaded_callback
# writing started 20.25372314453125 MB
# writing finished
# chunks_count 258
# submit task
# chunk_loaded_callback
# writing started 47.37890625 MB
# writing finishedsubmit task
#
# chunks_count 263
# chunk_loaded_callback
# writing started 18.58331298828125 MB
# writing finished
# chunks_count 265
# submit task
# chunk_loaded_callback
# writing started 27.58074951171875 MB
# writing finished
# chunks_count 268
# submit task
# chunk_loaded_callback
# writing started 22.5885009765625 MB
# writing finished
# chunks_count 270
# submit task
# chunk_loaded_callback
# writing started 18.37451171875 MB
# writing finished
# chunks_count 272
# submit task
# chunk_loaded_callback
# writing started 14.97674560546875 MB
# writing finished
# chunks_count 273
# submit task
# chunk_loaded_callback
# writing started 60.89404296875 MB
# writing finishedsubmit task
#
# chunks_count 279
# chunk_loaded_callback
# writing started 15.35638427734375 MB
# writing finished
# chunks_count 281
# submit task
# chunk_loaded_callback
# writing started 11.25628662109375 MB
# writing finished
# chunks_count 282
# submit task
# chunk_loaded_callback
# writing started 35.13555908203125 MB
# writing finished
# chunks_count 286
# submit task
# chunk_loaded_callback
# writing started 41.1148681640625 MB
# writing finished
# chunks_count 290
# submit task
# chunk_loaded_callback
# writing started 37.18560791015625 MB
# writing finished
# chunks_count 293
# submit task
# chunk_loaded_callback
# writing started 45.80340576171875 MB
# writing finishedsubmit task
#
# chunks_count 298
# chunk_loaded_callback
# writing started 34.8128662109375 MB
# writing finished
# chunks_count 302
# submit task
# chunk_loaded_callback
# writing started 30.04840087890625 MB
# writing finished
# chunks_count 305
# submit task
# chunk_loaded_callback
# writing started 30.978515625 MB
# writing finished
# chunks_count 308
# submit task
# chunk_loaded_callback
# writing started 37.432373046875 MB
# writing finished
# chunks_count 311
# submit task
# chunk_loaded_callback
# writing started 18.5643310546875 MB
# writing finished
# chunks_count 313
# submit task
# chunk_loaded_callback
# writing started 90.6197509765625 MB
# writing finishedsubmit task
#
# chunks_count 322
# chunk_loaded_callback
# writing started 82.8751220703125 MB
# writing finishedsubmit task
#
# chunks_count 331
# chunk_loaded_callback
# writing started 16.34344482421875 MB
# writing finished
# chunks_count 332
# submit task
# chunk_loaded_callback
# writing started 7.9344482421875 MB
# writing finished
# chunks_count 333
# submit task
# chunk_loaded_callback
# writing started 21.9810791015625 MB
# writing finished
# chunks_count 335
# submit task
# chunk_loaded_callback
# writing started 37.94488525390625 MB
# writing finished
# chunks_count 339
# submit task
# chunk_loaded_callback
# writing started 59.5653076171875 MB
# writing finishedsubmit task
#
# chunks_count 345
# chunk_loaded_callback
# writing started 73.6878662109375 MB
# writing finishedsubmit task
#
# chunks_count 352
# chunk_loaded_callback
# writing started 51.08038330078125 MB
# writing finishedsubmit task
#
# chunks_count 358
# chunk_loaded_callback
# writing started 32.74383544921875 MB
# writing finished
# chunks_count 361
# submit task
# chunk_loaded_callback
# writing started 37.5462646484375 MB
# writing finished
# chunks_count 365
# submit task
# chunk_loaded_callback
# writing started 30.143310546875 MB
# writing finished
# chunks_count 368
# submit task
# chunk_loaded_callback
# writing started 12.5660400390625 MB
# writing finished
# chunks_count 369
# submit task
# chunk_loaded_callback
# writing started 47.70159912109375 MB
# writing finishedsubmit task
#
# chunks_count 374
# chunk_loaded_callback
# writing started 53.85174560546875 MB
# writing finishedsubmit task
#
# chunks_count 379
# chunk_loaded_callback
# writing started 51.46002197265625 MB
# writing finishedsubmit task
#
# chunks_count 384
# chunk_loaded_callback
# writing started 42.23480224609375 MB
# writing finished
# chunks_count 388
# submit task
# chunk_loaded_callback
# writing started 59.31854248046875 MB
# writing finishedsubmit task
#
# chunks_count 394
# chunk_loaded_callback
# writing started 17.615234375 MB
# writing finished
# chunks_count 396
# submit task
# chunk_loaded_callback
# writing started 14.44525146484375 MB
# writing finished
# chunks_count 398
# submit task
# chunk_loaded_callback
# writing started 37.3564453125 MB
# writing finished
# chunks_count 401
# submit task
# chunk_loaded_callback
# writing started 36.7869873046875 MB
# writing finished
# chunks_count 405
# submit task
# chunk_loaded_callback
# writing started 30.5609130859375 MB
# writing finished
# chunks_count 408
# submit task
# chunk_loaded_callback
# writing started 17.7291259765625 MB
# writing finished
# chunks_count 410
# submit task
# chunk_loaded_callback
# writing started 8.427978515625 MB
# writing finished
# chunks_count 411
# submit task
# chunk_loaded_callback
# writing started 55.59808349609375 MB
# writing finishedsubmit task
#
# chunks_count 416
# chunk_loaded_callback
# writing started 65.20294189453125 MB
# writing finishedsubmit task
#
# chunks_count 423
# chunk_loaded_callback
# writing started 13.04058837890625 MB
# writing finished
# chunks_count 424
# submit task
# chunk_loaded_callback
# writing started 26.0811767578125 MB
# writing finished
# chunks_count 427
# submit task
# chunk_loaded_callback
# writing started 27.61871337890625 MB
# writing finished
# chunks_count 429
# submit task
# chunk_loaded_callback
# writing started 12.679931640625 MB
# writing finished
# chunks_count 431
# submit task
# chunk_loaded_callback
# writing started 47.96734619140625 MB
# writing finished
# chunks_count 435
# submit task
# chunk_loaded_callback
# writing started 43.88623046875 MB
# writing finishedsubmit task
#
# chunks_count 440
# chunk_loaded_callback
# writing started 49.22015380859375 MB
# writing finishedsubmit task
#
# chunks_count 445
# chunk_loaded_callback
# writing started 44.77838134765625 MB
# writing finished
# chunks_count 449
# submit task
# chunk_loaded_callback
# writing started 37.14764404296875 MB
# writing finished
# chunks_count 453
# submit task
# chunk_loaded_callback
# writing started 48.84051513671875 MB
# writing finishedsubmit task
#
# chunks_count 458
# chunk_loaded_callback
# writing started 19.7412109375 MB
# writing finished
# chunks_count 460
# submit task
# chunk_loaded_callback
# writing started 17.691162109375 MB
# writing finished
# chunks_count 462
# submit task
# chunk_loaded_callback
# writing started 45.9742431640625 MB
# writing finished
# chunks_count 466
# submit task
# chunk_loaded_callback
# writing started 37.03375244140625 MB
# writing finished
# chunks_count 470
# submit task
# chunk_loaded_callback
# writing started 20.272705078125 MB
# writing finished
# chunks_count 472
# submit task
# chunk_loaded_callback
# writing started 49.18218994140625 MB
# writing finishedsubmit task
#
# chunks_count 477
# chunk_loaded_callback
# writing started 22.75933837890625 MB
# writing finished
# chunks_count 479
# submit task
# chunk_loaded_callback
# writing started 8.82659912109375 MB
# writing finished
# chunks_count 480
# submit task
# chunk_loaded_callback
# writing started 15.0716552734375 MB
# writing finished
# chunks_count 482
# submit task
# chunk_loaded_callback
# writing started 26.89739990234375 MB
# writing finished
# chunks_count 484
# submit task
# chunk_loaded_callback
# writing started 27.78955078125 MB
# writing finished
# chunks_count 487
# submit task
# chunk_loaded_callback
# writing started 6.66265869140625 MB
# writing finished
# chunks_count 488
# submit task
# chunk_loaded_callback
# writing started 171.95733642578125 MB
# writing finishedsubmit task
#
# chunks_count 505
# chunk_loaded_callback
# writing started 27.2960205078125 MB
# writing finished
# chunks_count 508
# submit task
# chunk_loaded_callback
# writing started 52.37115478515625 MB
# writing finishedsubmit task
#
# chunks_count 513
# chunk_loaded_callback
# writing started 36.8629150390625 MB
# writing finished
# chunks_count 517
# submit task
# chunk_loaded_callback
# writing started 11.161376953125 MB
# writing finished
# chunks_count 518
# submit task
# chunk_loaded_callback
# writing started 37.07171630859375 MB
# writing finished
# chunks_count 521
# submit task
# chunk_loaded_callback
# writing started 8.427978515625 MB
# writing finished
# chunks_count 522
# submit task
# chunk_loaded_callback
# writing started 10.11737060546875 MB
# writing finished
# chunks_count 523
# submit task
# chunk_loaded_callback
# writing started 35.4962158203125 MB
# writing finished
# chunks_count 527
# submit task
# chunk_loaded_callback
# writing started 80.23663330078125 MB
# writing finishedsubmit task
#
# chunks_count 535
# chunk_loaded_callback
# writing started 39.9000244140625 MB
# writing finished
# chunks_count 539
# submit task
# chunk_loaded_callback
# writing started 63.399658203125 MB
# writing finishedsubmit task
#
# chunks_count 545
# chunk_loaded_callback
# writing started 38.647216796875 MB
# writing finished
# chunks_count 549
# submit task
# chunk_loaded_callback
# writing started 13.6290283203125 MB
# writing finished
# chunks_count 551
# submit task
# chunk_loaded_callback
# writing started 58.44537353515625 MB
# writing finishedsubmit task
#
# chunks_count 556
# chunk_loaded_callback
# writing started 52.48504638671875 MB
# writing finishedsubmit task
#
# chunks_count 562
# chunk_loaded_callback
# writing started 21.20281982421875 MB
# writing finished
# chunks_count 564
# submit task
# chunk_loaded_callback
# writing started 94.3402099609375 MB
# writing finishedsubmit task
#
# chunks_count 573
# chunk_loaded_callback
# writing started 15.109619140625 MB
# writing finished
# chunks_count 575
# submit task
# chunk_loaded_callback
# writing started 12.7178955078125 MB
# writing finished
# chunks_count 576
# submit task
# chunk_loaded_callback
# writing started 44.39874267578125 MB
# writing finished
# chunks_count 580
# submit task
# chunk_loaded_callback
# writing started 18.7161865234375 MB
# writing finished
# chunks_count 582
# submit task
# chunk_loaded_callback
# writing started 44.721435546875 MB
# writing finishedsubmit task
#
# chunks_count 587
# chunk_loaded_callback
# writing started 24.4107666015625 MB
# writing finished
# chunks_count 589
# submit task
# chunk_loaded_callback
# writing started 65.01312255859375 MB
# writing finishedsubmit task
#
# chunks_count 596
# chunk_loaded_callback
# writing started 25.35986328125 MB
# writing finished
# chunks_count 598
# submit task
# chunk_loaded_callback
# writing started 59.1856689453125 MB
# writing finishedsubmit task
#
# chunks_count 604
# chunk_loaded_callback
# writing started 21.183837890625 MB
# writing finished
# chunks_count 606
# submit task
# chunk_loaded_callback
# writing started 66.60760498046875 MB
# writing finishedsubmit task
#
# chunks_count 613
# chunk_loaded_callback
# writing started 32.02252197265625 MB
# writing finished
# chunks_count 616
# submit task
# chunk_loaded_callback
# writing started 22.00006103515625 MB
# writing finished
# chunks_count 618
# submit task
# chunk_loaded_callback
# writing started 23.157958984375 MB
# writing finished
# chunks_count 621
# submit task
# chunk_loaded_callback
# writing started 48.95440673828125 MB
# writing finishedsubmit task
#
# chunks_count 626
# chunk_loaded_callback
# writing started 48.34698486328125 MB
# writing finished
# chunks_count 630
# submit task
# chunk_loaded_callback
# writing started 21.487548828125 MB
# writing finished
# chunks_count 633
# submit task
# chunk_loaded_callback
# writing started 60.49542236328125 MB
# writing finishedsubmit task
#
# chunks_count 639
# chunk_loaded_callback
# writing started 56.110595703125 MB
# writing finishedsubmit task
#
# chunks_count 644
# chunk_loaded_callback
# writing started 23.44268798828125 MB
# writing finished
# chunks_count 647
# submit task
# chunk_loaded_callback
# writing started 16.15362548828125 MB
# writing finished
# chunks_count 648
# submit task
# chunk_loaded_callback
# writing started 46.56268310546875 MB
# writing finishedsubmit task
#
# chunks_count 653
# chunk_loaded_callback
# writing started 22.4366455078125 MB
# writing finished
# chunks_count 655
# submit task
# chunk_loaded_callback
# writing started 23.9931640625 MB
# writing finished
# chunks_count 658
# submit task
# chunk_loaded_callback
# writing started 21.8292236328125 MB
# writing finished
# chunks_count 660
# submit task
# chunk_loaded_callback
# writing started 20.880126953125 MB
# writing finished
# chunks_count 662
# submit task
# chunk_loaded_callback
# writing started 17.615234375 MB
# writing finished
# chunks_count 664
# submit task
# chunk_loaded_callback
# writing started 45.10107421875 MB
# writing finished
# chunks_count 668
# submit task
# chunk_loaded_callback
# writing started 51.554931640625 MB
# writing finishedsubmit task
#
# chunks_count 673
# chunk_loaded_callback
# writing started 35.002685546875 MB
# writing finished
# chunks_count 677
# submit task
# chunk_loaded_callback
# writing started 22.56951904296875 MB
# writing finished
# chunks_count 679
# submit task
# chunk_loaded_callback
# writing started 25.51171875 MB
# writing finished
# chunks_count 682
# submit task
# chunk_loaded_callback
# writing started 30.01043701171875 MB
# writing finished
# chunks_count 685
# submit task
# chunk_loaded_callback
# writing started 25.66357421875 MB
# writing finished
# chunks_count 687
# submit task
# chunk_loaded_callback
# writing started 28.37799072265625 MB
# writing finished
# chunks_count 690
# submit task
# chunk_loaded_callback
# writing started 62.9061279296875 MB
# writing finishedsubmit task
#
# chunks_count 696
# chunk_loaded_callback
# writing started 38.93194580078125 MB
# writing finished
# chunks_count 700
# submit task
# chunk_loaded_callback
# writing started 48.0242919921875 MB
# writing finishedsubmit task
#
# chunks_count 705
# chunk_loaded_callback
# writing started 19.26666259765625 MB
# writing finished
# chunks_count 707
# submit task
# chunk_loaded_callback
# writing started 11.009521484375 MB
# writing finished
# chunks_count 708
# submit task
# chunk_loaded_callback
# writing started 34.33831787109375 MB
# writing finished
# chunks_count 712
# submit task
# chunk_loaded_callback
# writing started 19.26666259765625 MB
# writing finished
# chunks_count 713
# submit task
# chunk_loaded_callback
# writing started 16.87493896484375 MB
# writing finished
# chunks_count 715
# submit task
# chunk_loaded_callback
# writing started 41.4945068359375 MB
# writing finished
# chunks_count 719
# submit task
# chunk_loaded_callback
# writing started 10.53497314453125 MB
# writing finished
# chunks_count 720
# submit task
# chunk_loaded_callback
# writing started 27.5997314453125 MB
# writing finished
# chunks_count 723
# submit task
# chunk_loaded_callback
# writing started 44.341796875 MB
# writing finishedsubmit task
#
# chunks_count 728
# chunk_loaded_callback
# writing started 45.10107421875 MB
# writing finished
# chunks_count 732
# submit task
# chunk_loaded_callback
# writing started 36.29345703125 MB
# writing finished
# chunks_count 736
# submit task
# chunk_loaded_callback
# writing started 26.93536376953125 MB
# writing finished
# chunks_count 738
# submit task
# chunk_loaded_callback
# writing started 71.80865478515625 MB
# writing finishedsubmit task
#
# chunks_count 746
# chunk_loaded_callback
# writing started 46.4677734375 MB
# writing finished
# chunks_count 750
# submit task
# chunk_loaded_callback
# writing started 19.87408447265625 MB
# writing finished
# chunks_count 752
# submit task
# chunk_loaded_callback
# writing started 18.22265625 MB
# writing finished
# chunks_count 754
# submit task
# chunk_loaded_callback
# writing started 93.2012939453125 MB
# writing finishedsubmit task
#
# chunks_count 763
# chunk_loaded_callback
# writing started 78.71807861328125 MB
# writing finishedsubmit task
#
# chunks_count 771
# chunk_loaded_callback
# writing started 30.0673828125 MB
# writing finished
# chunks_count 774
# submit task
# chunk_loaded_callback
# writing started 51.0614013671875 MB
# writing finishedsubmit task
#
# chunks_count 779
# chunk_loaded_callback
# writing started 42.76629638671875 MB
# writing finishedsubmit task
#
# chunks_count 784
# chunk_loaded_callback
# writing started 8.50390625 MB
# writing finishedsubmit task
#
# chunks_count 785
# chunk_loaded_callback
# writing started 17.48236083984375 MB
# writing finished
# chunks_count 786
# submit task
# chunk_loaded_callback
# writing started 46.98028564453125 MB
# writing finished
# chunks_count 791
# submit task
# chunk_loaded_callback
# writing started 39.02685546875 MB
# writing finished
# chunks_count 795
# submit task
# chunk_loaded_callback
# writing started 25.132080078125 MB
# writing finished
# chunks_count 797
# submit task
# chunk_loaded_callback
# writing started 72.68182373046875 MB
# writing finishedsubmit task
#
# chunks_count 805
# chunk_loaded_callback
# writing started 11.33221435546875 MB
# writing finished
# chunks_count 806
# submit task
# chunk_loaded_callback
# writing started 84.26080322265625 MB
# writing finishedsubmit task
#
# chunks_count 814
# chunk_loaded_callback
# writing started 55.14251708984375 MB
# writing finishedsubmit task
#
# chunks_count 820
# chunk_loaded_callback
# writing started 38.647216796875 MB
# writing finished
# chunks_count 824
# submit task
# chunk_loaded_callback
# writing started 38.0018310546875 MB
# writing finished
# chunks_count 827
# submit task
# chunk_loaded_callback
# writing started 23.6514892578125 MB
# writing finished
# chunks_count 830
# submit task
# chunk_loaded_callback
# writing started 37.03375244140625 MB
# writing finished
# chunks_count 834
# submit task
# chunk_loaded_callback
# writing started 38.74212646484375 MB
# writing finished
# chunks_count 837
# submit task
# chunk_loaded_callback
# writing started 25.83441162109375 MB
# writing finished
# chunks_count 840
# submit task
# chunk_loaded_callback
# writing started 46.771484375 MB
# writing finishedsubmit task
#
# chunks_count 845
# chunk_loaded_callback
# writing started 12.6419677734375 MB
# writing finished
# chunks_count 846
# submit task
# chunk_loaded_callback
# writing started 31.5859375 MB
# writing finished
# chunks_count 849
# submit task
# chunk_loaded_callback
# writing started 13.6669921875 MB
# writing finished
# chunks_count 851
# submit task
# chunk_loaded_callback
# writing started 39.00787353515625 MB
# writing finished
# chunks_count 854
# submit task
# chunk_loaded_callback
# writing started 11.71185302734375 MB
# writing finished
# chunks_count 856
# submit task
# chunk_loaded_callback
# writing started 36.76800537109375 MB
# writing finished
# chunks_count 859
# submit task
# chunk_loaded_callback
# writing started 12.831787109375 MB
# writing finished
# chunks_count 861
# submit task
# chunk_loaded_callback
# writing started 24.3348388671875 MB
# writing finished
# chunks_count 863
# submit task
# chunk_loaded_callback
# writing started 66.05712890625 MB
# writing finishedsubmit task
#
# chunks_count 870
# chunk_loaded_callback
# writing started 29.8775634765625 MB
# writing finished
# chunks_count 873
# submit task
# chunk_loaded_callback
# writing started 47.70159912109375 MB
# writing finished
# chunks_count 877
# submit task
# chunk_loaded_callback
# writing started 49.732666015625 MB
# writing finishedsubmit task
#
# chunks_count 882
# chunk_loaded_callback
# writing started 6.9473876953125 MB
# writing finished
# chunks_count 883
# submit task
# chunk_loaded_callback
# writing started 22.60748291015625 MB
# writing finished
# chunks_count 885
# submit task
# chunk_loaded_callback
# writing started 41.70330810546875 MB
# writing finishedsubmit task
#
# chunks_count 890
# chunk_loaded_callback
# writing started 23.765380859375 MB
# writing finished
# chunks_count 892
# submit task
# chunk_loaded_callback
# writing started 58.82501220703125 MB
# writing finishedsubmit task
#
# chunks_count 898
# chunk_loaded_callback
# writing started 43.962158203125 MB
# writing finished
# chunks_count 902
# submit task
# chunk_loaded_callback
# writing started 17.14068603515625 MB
# writing finished
# chunks_count 904
# submit task
# chunk_loaded_callback
# writing started 61.6912841796875 MB
# writing finishedsubmit task
#
# chunks_count 910
# chunk_loaded_callback
# writing started 48.34698486328125 MB
# writing finishedsubmit task
#
# chunks_count 915
# chunk_loaded_callback
# writing started 33.31329345703125 MB
# writing finished
# chunks_count 918
# submit task
# chunk_loaded_callback
# writing started 82.7991943359375 MB
# writing finishedsubmit task
#
# chunks_count 927
# chunk_loaded_callback
# writing started 22.2847900390625 MB
# writing finished
# chunks_count 929
# submit task
# chunk_loaded_callback
# writing started 39.76715087890625 MB
# writing finished
# chunks_count 933
# submit task
# chunk_loaded_callback
# writing started 28.18817138671875 MB
# writing finished
# chunks_count 936
# submit task
# chunk_loaded_callback
# writing started 30.2572021484375 MB
# writing finished
# chunks_count 939
# submit task
# chunk_loaded_callback
# writing started 11.10443115234375 MB
# writing finished
# chunks_count 940
# submit task
# chunk_loaded_callback
# writing started 44.89227294921875 MB
# writing finished
# chunks_count 944
# submit task
# chunk_loaded_callback
# writing started 17.89996337890625 MB
# writing finished
# chunks_count 946
# submit task
# chunk_loaded_callback
# writing started 35.62908935546875 MB
# writing finished
# chunks_count 950
# submit task
# chunk_loaded_callback
# writing started 53.073486328125 MB
# writing finishedsubmit task
#
# chunks_count 955
# chunk_loaded_callback
# writing started 12.77484130859375 MB
# writing finished
# chunks_count 956
# submit task
# chunk_loaded_callback
# writing started 48.9354248046875 MB
# writing finishedsubmit task
#
# chunks_count 961
# chunk_loaded_callback
# writing started 73.28924560546875 MB
# writing finishedsubmit task
#
# chunks_count 968
# chunk_loaded_callback
# writing started 25.53070068359375 MB
# writing finished
# chunks_count 971
# submit task
# chunk_loaded_callback
# writing started 35.40130615234375 MB
# writing finished
# chunks_count 975
# submit task
# chunk_loaded_callback
# writing started 22.5125732421875 MB
# writing finished
# chunks_count 977
# submit task
# chunk_loaded_callback
# writing started 18.05181884765625 MB
# writing finished
# chunks_count 979
# submit task
# chunk_loaded_callback
# writing started 51.8966064453125 MB
# writing finishedsubmit task
#
# chunks_count 984
# chunk_loaded_callback
# writing started 36.61614990234375 MB
# writing finished
# chunks_count 987
# submit task
# chunk_loaded_callback
# writing started 10.47802734375 MB
# writing finished
# chunks_count 988
# submit task
# chunk_loaded_callback
# writing started 13.38226318359375 MB
# writing finished
# chunks_count 990
# submit task
# chunk_loaded_callback
# writing started 46.60064697265625 MB
# writing finishedsubmit task
#
# chunks_count 995
# chunk_loaded_callback
# writing started 31.30120849609375 MB
# writing finished
# chunks_count 998
# submit task
# chunk_loaded_callback
# writing started 48.91644287109375 MB
# writing finishedsubmit task
#
# chunks_count 1003
# chunk_loaded_callback
# writing started 51.858642578125 MB
# writing finishedsubmit task
#
# chunks_count 1008
# chunk_loaded_callback
# writing started 15.79296875 MB
# writing finished
# chunks_count 1009
# submit task
# chunk_loaded_callback
# writing started 23.97418212890625 MB
# writing finished
# chunks_count 1012
# submit task
# chunk_loaded_callback
# writing started 51.42205810546875 MB
# writing finishedsubmit task
#
# chunks_count 1017
# chunk_loaded_callback
# writing started 37.50830078125 MB
# writing finished
# chunks_count 1021
# submit task
# chunk_loaded_callback
# writing started 56.869873046875 MB
# writing finishedsubmit task
#
# chunks_count 1026
# chunk_loaded_callback
# writing started 65.65850830078125 MB
# writing finished
# chunks_count 1033
# submit task
# chunk_loaded_callback
# writing started 27.48583984375 MB
# writing finished
# chunks_count 1036
# submit task
# chunk_loaded_callback
# writing started 43.810302734375 MB
# writing finished
# chunks_count 1040
# submit task
# chunk_loaded_callback
# writing started 32.85772705078125 MB
# writing finished
# chunks_count 1043
# submit task
# chunk_loaded_callback
# writing started 36.7490234375 MB
# writing finished
# chunks_count 1047
# submit task
# chunk_loaded_callback
# writing started 56.869873046875 MB
# writing finished
# chunks_count 1053
# submit task
# chunk_loaded_callback
# writing started 23.1959228515625 MB
# writing finished
# chunks_count 1055
# submit task
# chunk_loaded_callback
# writing started 58.540283203125 MB
# writing finishedsubmit task
#
# chunks_count 1061
# chunk_loaded_callback
# writing started 39.04583740234375 MB
# writing finished
# chunks_count 1065
# submit task
# chunk_loaded_callback
# writing started 55.806884765625 MB
# writing finishedsubmit task
#
# chunks_count 1070
# chunk_loaded_callback
# writing started 23.4237060546875 MB
# writing finished
# chunks_count 1073
# submit task
# chunk_loaded_callback
# writing started 36.88189697265625 MB
# writing finished
# chunks_count 1076
# submit task
# chunk_loaded_callback
# writing started 75.94671630859375 MB
# writing finishedsubmit task
#
# chunks_count 1084
# chunk_loaded_callback
# writing started 11.69287109375 MB
# writing finished
# chunks_count 1085
# submit task
# chunk_loaded_callback
# writing started 30.1812744140625 MB
# writing finished
# chunks_count 1088
# submit task
# chunk_loaded_callback
# writing started 34.8887939453125 MB
# writing finished
# chunks_count 1092
# submit task
# chunk_loaded_callback
# writing started 11.768798828125 MB
# writing finished
# chunks_count 1093
# submit task
# chunk_loaded_callback
# writing started 6.81451416015625 MB
# writing finished
# chunks_count 1094
# submit task
# chunk_loaded_callback
# writing started 38.875 MB
# writing finished
# chunks_count 1097
# submit task
# chunk_loaded_callback
# writing started 38.96990966796875 MB
# writing finished
# chunks_count 1101
# submit task
# chunk_loaded_callback
# writing started 25.87237548828125 MB
# writing finished
# chunks_count 1104
# submit task
# chunk_loaded_callback
# writing started 115.9796142578125 MB
# writing finishedsubmit task
#
# chunks_count 1116
# chunk_loaded_callback
# writing started 55.78790283203125 MB
# writing finishedsubmit task
#
# chunks_count 1121
# chunk_loaded_callback
# writing started 13.439208984375 MB
# writing finished
# chunks_count 1123
# submit task
# chunk_loaded_callback
# writing started 33.31329345703125 MB
# writing finished
# chunks_count 1126
# submit task
# chunk_loaded_callback
# writing started 46.088134765625 MB
# writing finished
# chunks_count 1130
# submit task
# chunk_loaded_callback
# writing started 27.35296630859375 MB
# writing finished
# chunks_count 1133
# submit task
# chunk_loaded_callback
# writing started 15.05267333984375 MB
# writing finished
# chunks_count 1135
# submit task
# chunk_loaded_callback
# writing started 54.68695068359375 MB
# writing finishedsubmit task
#
# chunks_count 1140
# chunk_loaded_callback
# writing started 7.7825927734375 MB
# writing finishedsubmit task
#
# chunks_count 1141
# chunk_loaded_callback
# writing started 6.54876708984375 MB
# writing finished
# chunks_count 1142
# submit task
# chunk_loaded_callback
# writing started 37.6221923828125 MB
# writing finished
# chunks_count 1145
# submit task
# chunk_loaded_callback
# writing started 43.7723388671875 MB
# writing finishedsubmit task
#
# chunks_count 1150
# chunk_loaded_callback
# writing started 23.55657958984375 MB
# writing finished
# chunks_count 1152
# submit task
# chunk_loaded_callback
# writing started 88.076171875 MB
# writing finishedsubmit task
#
# chunks_count 1161
# chunk_loaded_callback
# writing started 24.96124267578125 MB
# writing finished
# chunks_count 1163
# submit task
# chunk_loaded_callback
# writing started 17.6531982421875 MB
# writing finished
# chunks_count 1165
# submit task
# chunk_loaded_callback
# writing started 46.8094482421875 MB
# writing finishedsubmit task
#
# chunks_count 1170
# chunk_loaded_callback
# writing started 19.60833740234375 MB
# writing finished
# chunks_count 1172
# submit task
# chunk_loaded_callback
# writing started 39.23565673828125 MB
# writing finished
# chunks_count 1176
# submit task
# chunk_loaded_callback
# writing started 29.5738525390625 MB
# writing finished
# chunks_count 1179
# submit task
# chunk_loaded_callback
# writing started 7.364990234375 MB
# writing finished
# chunks_count 1180
# submit task
# chunk_loaded_callback
# writing started 14.63507080078125 MB
# writing finished
# chunks_count 1181
# submit task
# chunk_loaded_callback
# writing started 13.51513671875 MB
# writing finished
# chunks_count 1182
# submit task
# chunk_loaded_callback
# writing started 46.6575927734375 MB
# writing finishedsubmit task
#
# chunks_count 1187
# chunk_loaded_callback
# writing started 54.592041015625 MB
# writing finished
# chunks_count 1192
# submit task
# chunk_loaded_callback
# writing started 26.8404541015625 MB
# writing finished
# chunks_count 1195
# submit task
# chunk_loaded_callback
# writing started 43.6964111328125 MB
# writing finishedsubmit task
#
# chunks_count 1200
# chunk_loaded_callback
# writing started 23.78436279296875 MB
# writing finished
# chunks_count 1202
# submit task
# chunk_loaded_callback
# writing started 56.77496337890625 MB
# writing finishedsubmit task
#
# chunks_count 1208
# chunk_loaded_callback
# writing started 26.32794189453125 MB
# writing finished
# chunks_count 1210
# submit task
# chunk_loaded_callback
# writing started 29.535888671875 MB
# writing finished
# chunks_count 1213
# submit task
# chunk_loaded_callback
# writing started 73.95361328125 MB
# writing finishedsubmit task
#
# chunks_count 1221
# chunk_loaded_callback
# writing started 55.02862548828125 MB
# writing finishedsubmit task
#
# chunks_count 1226
# chunk_loaded_callback
# writing started 29.25115966796875 MB
# writing finished
# chunks_count 1229
# submit task
# chunk_loaded_callback
# writing started 49.48590087890625 MB
# writing finishedsubmit task
#
# chunks_count 1234
# chunk_loaded_callback
# writing started 6.7955322265625 MB
# writing finished
# chunks_count 1235
# submit task
# chunk_loaded_callback
# writing started 46.37286376953125 MB
# writing finished
# chunks_count 1239
# submit task
# chunk_loaded_callback
# writing started 37.64117431640625 MB
# writing finished
# chunks_count 1243
# submit task
# chunk_loaded_callback
# writing started 53.90869140625 MB
# writing finished
# chunks_count 1249
# submit task
# chunk_loaded_callback
# writing started 41.81719970703125 MB
# writing finished
# chunks_count 1253
# submit task
# chunk_loaded_callback
# writing started 34.47119140625 MB
# writing finished
# chunks_count 1256
# submit task
# chunk_loaded_callback
# writing started 17.0078125 MB
# writing finished
# chunks_count 1258
# submit task
# chunk_loaded_callback
# writing started 43.90521240234375 MB
# writing finished
# chunks_count 1262
# submit task
# chunk_loaded_callback
# writing started 29.74468994140625 MB
# writing finished
# chunks_count 1265
# submit task
# chunk_loaded_callback
# writing started 8.48492431640625 MB
# writing finished
# chunks_count 1266
# submit task
# chunk_loaded_callback
# writing started 16.11566162109375 MB
# writing finished
# chunks_count 1268
# submit task
# chunk_loaded_callback
# writing started 35.51519775390625 MB
# writing finished
# chunks_count 1271
# submit task
# chunk_loaded_callback
# writing started 52.02947998046875 MB
# writing finishedsubmit task
#
# chunks_count 1276
# chunk_loaded_callback
# writing started 53.6429443359375 MB
# writing finishedsubmit task
#
# chunks_count 1282
# chunk_loaded_callback
# writing started 31.60491943359375 MB
# writing finished
# chunks_count 1285
# submit task
# chunk_loaded_callback
# writing started 53.4151611328125 MB
# writing finishedsubmit task
#
# chunks_count 1290
# chunk_loaded_callback
# writing started 59.7171630859375 MB
# writing finishedsubmit task
#
# chunks_count 1296
# chunk_loaded_callback
# writing started 52.29522705078125 MB
# writing finishedsubmit task
#
# chunks_count 1302
# chunk_loaded_callback
# writing started 25.7015380859375 MB
# writing finished
# chunks_count 1304
# submit task
# chunk_loaded_callback
# writing started 35.3443603515625 MB
# writing finished
# chunks_count 1308
# submit task
# chunk_loaded_callback
# writing started 18.6402587890625 MB
# writing finished
# chunks_count 1310
# submit task
# chunk_loaded_callback
# writing started 23.21490478515625 MB
# writing finished
# chunks_count 1312
# submit task
# chunk_loaded_callback
# writing started 86.42474365234375 MB
# writing finishedsubmit task
#
# chunks_count 1321
# chunk_loaded_callback
# writing started 9.32012939453125 MB
# writing finished
# chunks_count 1321
# submit task
# chunk_loaded_callback
# writing started 15.33740234375 MB
# writing finished
# chunks_count 1323
# submit task
# chunk_loaded_callback
# writing started 53.73785400390625 MB
# writing finishedsubmit task
#
# chunks_count 1328
# chunk_loaded_callback
# writing started 24.65753173828125 MB
# writing finished
# chunks_count 1331
# submit task
# chunk_loaded_callback
# writing started 22.37969970703125 MB
# writing finished
# chunks_count 1333
# submit task
# chunk_loaded_callback
# writing started 63.57049560546875 MB
# writing finishedsubmit task
#
# chunks_count 1339
# chunk_loaded_callback
# writing started 18.37451171875 MB
# writing finished
# chunks_count 1341
# submit task
# chunk_loaded_callback
# writing started 25.56866455078125 MB
# writing finished
# chunks_count 1344
# submit task
# chunk_loaded_callback
# writing started 72.87164306640625 MB
# writing finishedsubmit task
#
# chunks_count 1351
# chunk_loaded_callback
# writing started 41.01995849609375 MB
# writing finished
# chunks_count 1355
# submit task
# chunk_loaded_callback
# writing started 41.43756103515625 MB
# writing finished
# chunks_count 1359
# submit task
# chunk_loaded_callback
# writing started 37.07171630859375 MB
# writing finished
# chunks_count 1363
# submit task
# chunk_loaded_callback
# writing started 14.5401611328125 MB
# writing finished
# chunks_count 1365
# submit task
# chunk_loaded_callback
# writing started 11.67388916015625 MB
# writing finished
# chunks_count 1366
# submit task
# chunk_loaded_callback
# writing started 32.6109619140625 MB
# writing finished
# chunks_count 1369
# submit task
# chunk_loaded_callback
# writing started 18.73516845703125 MB
# writing finished
# chunks_count 1371
# submit task
# chunk_loaded_callback
# writing started 33.2183837890625 MB
# writing finished
# chunks_count 1374
# submit task
# chunk_loaded_callback
# writing started 30.8646240234375 MB
# writing finished
# chunks_count 1377
# submit task
# chunk_loaded_callback
# writing started 34.015625 MB
# writing finished
# chunks_count 1381
# submit task
# chunk_loaded_callback
# writing started 24.65753173828125 MB
# writing finished
# chunks_count 1383
# submit task
# chunk_loaded_callback
# writing started 41.4945068359375 MB
# writing finished
# chunks_count 1387
# submit task
# chunk_loaded_callback
# writing started 35.458251953125 MB
# writing finished
# chunks_count 1391
# submit task
# chunk_loaded_callback
# writing started 16.64715576171875 MB
# writing finished
# chunks_count 1393
# submit task
# chunk_loaded_callback
# writing started 41.36163330078125 MB
# writing finished
# chunks_count 1397
# submit task
# chunk_loaded_callback
# writing started 37.7740478515625 MB
# writing finished
# chunks_count 1400
# submit task
# chunk_loaded_callback
# writing started 20.10186767578125 MB
# writing finishedsubmit task
#
# chunks_count 1403
# chunk_loaded_callback
# writing started 34.698974609375 MB
# writing finished
# chunks_count 1406
# submit task
# chunk_loaded_callback
# writing started 31.8516845703125 MB
# writing finished
# chunks_count 1409
# submit task
# chunk_loaded_callback
# writing started 48.1002197265625 MB
# writing finishedsubmit task
#
# chunks_count 1414
# chunk_loaded_callback
# writing started 53.16839599609375 MB
# writing finishedsubmit task
#
# chunks_count 1419
# chunk_loaded_callback
# writing started 66.7025146484375 MB
# writing finishedsubmit task
#
# chunks_count 1426
# chunk_loaded_callback
# writing started 41.39959716796875 MB
# writing finished
# chunks_count 1430
# submit task
# chunk_loaded_callback
# writing started 28.321044921875 MB
# writing finished
# chunks_count 1433
# submit task
# chunk_loaded_callback
# writing started 10.91461181640625 MB
# writing finished
# chunks_count 1434
# submit task
# chunk_loaded_callback
# writing started 41.4185791015625 MB
# writing finished
# chunks_count 1438
# submit task
# chunk_loaded_callback
# writing started 16.64715576171875 MB
# writing finished
# chunks_count 1440
# submit task
# chunk_loaded_callback
# writing started 27.9793701171875 MB
# writing finished
# chunks_count 1443
# submit task
# chunk_loaded_callback
# writing started 41.836181640625 MB
# writing finished
# chunks_count 1447
# submit task
# chunk_loaded_callback
# writing started 53.2633056640625 MB
# writing finishedsubmit task
#
# chunks_count 1452
# chunk_loaded_callback
# writing started 36.65411376953125 MB
# writing finished
# chunks_count 1456
# submit task
# chunk_loaded_callback
# writing started 16.4383544921875 MB
# writing finished
# chunks_count 1458
# submit task
# chunk_loaded_callback
# writing started 14.40728759765625 MB
# writing finished
# chunks_count 1459
# submit task
# chunk_loaded_callback
# writing started 14.8438720703125 MB
# writing finished
# chunks_count 1460
# submit task
# chunk_loaded_callback
# writing started 47.43585205078125 MB
# writing finishedsubmit task
#
# chunks_count 1465
# chunk_loaded_callback
# writing started 7.91546630859375 MB
# writing finishedsubmit task
#
# chunks_count 1466
# chunk_loaded_callback
# writing started 46.56268310546875 MB
# writing finishedsubmit task
#
# chunks_count 1471
# chunk_loaded_callback
# writing started 34.45220947265625 MB
# writing finished
# chunks_count 1474
# submit task
# chunk_loaded_callback
# writing started 40.98199462890625 MB
# writing finished
# chunks_count 1478
# submit task
# chunk_loaded_callback
# writing started 61.121826171875 MB
# writing finishedsubmit task
#
# chunks_count 1484
# chunk_loaded_callback
# writing started 19.72222900390625 MB
# writing finished
# chunks_count 1486
# submit task
# chunk_loaded_callback
# writing started 34.9267578125 MB
# writing finished
# chunks_count 1490
# submit task
# chunk_loaded_callback
# writing started 33.028564453125 MB
# writing finished
# chunks_count 1493
# submit task
# chunk_loaded_callback
# writing started 27.94140625 MB
# writing finished
# chunks_count 1496
# submit task
# chunk_loaded_callback
# writing started 25.8533935546875 MB
# writing finished
# chunks_count 1499
# submit task
# chunk_loaded_callback
# writing started 20.19677734375 MB
# writing finished
# chunks_count 1501
# submit task
# chunk_loaded_callback
# writing started 73.78277587890625 MB
# writing finishedsubmit task
#
# chunks_count 1508
# chunk_loaded_callback
# writing started 19.1717529296875 MB
# writing finished
# chunks_count 1510
# submit task
# chunk_loaded_callback
# writing started 26.63165283203125 MB
# writing finished
# chunks_count 1513
# submit task
# chunk_loaded_callback
# writing started 36.95782470703125 MB
# writing finished
# chunks_count 1516
# submit task
# chunk_loaded_callback
# writing started 28.0552978515625 MB
# writing finished
# chunks_count 1519
# submit task
# chunk_loaded_callback
# writing started 50.2261962890625 MB
# writing finishedsubmit task
#
# chunks_count 1524
# chunk_loaded_callback
# writing started 12.30029296875 MB
# writing finished
# chunks_count 1525
# submit task
# chunk_loaded_callback
# writing started 136.0245361328125 MB
# writing finishedsubmit task
#
# chunks_count 1539
# chunk_loaded_callback
# writing started 26.21405029296875 MB
# writing finished
# chunks_count 1542
# submit task
# chunk_loaded_callback
# writing started 22.6644287109375 MB
# writing finished
# chunks_count 1544
# submit task
# chunk_loaded_callback
# writing started 18.5263671875 MB
# writing finished
# chunks_count 1546
# submit task
# chunk_loaded_callback
# writing started 8.29510498046875 MB
# writing finished
# chunks_count 1546
# submit task
# chunk_loaded_callback
# writing started 34.18646240234375 MB
# writing finished
# chunks_count 1550
# submit task
# chunk_loaded_callback
# writing started 50.20721435546875 MB
# writing finishedsubmit task
#
# chunks_count 1555
# chunk_loaded_callback
# writing started 71.144287109375 MB
# writing finishedsubmit task
#
# chunks_count 1562
# chunk_loaded_callback
# writing started 22.4366455078125 MB
# writing finished
# chunks_count 1564
# submit task
# chunk_loaded_callback
# writing started 12.6419677734375 MB
# writing finished
# chunks_count 1566
# submit task
# chunk_loaded_callback
# writing started 48.517822265625 MB
# writing finished
# chunks_count 1570
# submit task
# chunk_loaded_callback
# writing started 37.45135498046875 MB
# writing finished
# chunks_count 1574
# submit task
# chunk_loaded_callback
# writing started 33.8258056640625 MB
# writing finished
# chunks_count 1578
# submit task
# chunk_loaded_callback
# writing started 66.208984375 MB
# writing finishedsubmit task
#
# chunks_count 1584
# chunk_loaded_callback
# writing started 27.12518310546875 MB
# writing finished
# chunks_count 1587
# submit task
# chunk_loaded_callback
# writing started 26.6126708984375 MB
# writing finished
# chunks_count 1590
# submit task
# chunk_loaded_callback
# writing started 19.57037353515625 MB
# writing finished
# chunks_count 1592
# submit task
# chunk_loaded_callback
# writing started 61.59637451171875 MB
# writing finishedsubmit task
#
# chunks_count 1598
# chunk_loaded_callback
# writing started 52.2003173828125 MB
# writing finishedsubmit task
#
# chunks_count 1603
# chunk_loaded_callback
# writing started 55.3133544921875 MB
# writing finishedsubmit task
#
# chunks_count 1608
# chunk_loaded_callback
# writing started 26.8404541015625 MB
# writing finished
# chunks_count 1611
# submit task
# chunk_loaded_callback
# writing started 32.3831787109375 MB
# writing finished
# chunks_count 1614
# submit task
# chunk_loaded_callback
# writing started 32.32623291015625 MB
# writing finished
# chunks_count 1618
# submit task
# chunk_loaded_callback
# writing started 23.44268798828125 MB
# writing finished
# chunks_count 1620
# submit task
# chunk_loaded_callback
# writing started 22.7403564453125 MB
# writing finished
# chunks_count 1622
# submit task
# chunk_loaded_callback
# writing started 15.7550048828125 MB
# writing finished
# chunks_count 1624
# submit task
# chunk_loaded_callback
# writing started 25.3978271484375 MB
# writing finished
# chunks_count 1626
# submit task
# chunk_loaded_callback
# writing started 22.32275390625 MB
# writing finished
# chunks_count 1629
# submit task
# chunk_loaded_callback
# writing started 23.23388671875 MB
# writing finished
# chunks_count 1631
# submit task
# chunk_loaded_callback
# writing started 7.13720703125 MB
# writing finished
# chunks_count 1632
# submit task
# chunk_loaded_callback
# writing started 54.1744384765625 MB
# writing finished
# chunks_count 1637
# submit task
# chunk_loaded_callback
# writing started 31.965576171875 MB
# writing finished
# chunks_count 1640
# submit task
# chunk_loaded_callback
# writing started 9.6807861328125 MB
# writing finished
# chunks_count 1641
# submit task
# chunk_loaded_callback
# writing started 79.74310302734375 MB
# writing finishedsubmit task
#
# chunks_count 1649
# chunk_loaded_callback
# writing started 18.16571044921875 MB
# writing finished
# chunks_count 1651
# submit task
# chunk_loaded_callback
# writing started 8.63677978515625 MB
# writing finished
# chunks_count 1652
# submit task
# chunk_loaded_callback
# writing started 32.85772705078125 MB
# writing finished
# chunks_count 1655
# submit task
# chunk_loaded_callback
# writing started 31.8896484375 MB
# writing finished
# chunks_count 1658
# submit task
# chunk_loaded_callback
# writing started 28.64373779296875 MB
# writing finished
# chunks_count 1661
# submit task
# chunk_loaded_callback
# ...
# writing finished
# chunks_count 6815
# submit task
# chunk_loaded_callback
# writing started 9.794677734375 MB
# writing finished
# chunks_count 6816
# submit task
# chunk_loaded_callback
# writing started 4.70751953125 MB
# writing finished
# chunks_count 6817
# submit task
# chunk_loaded_callback
# writing started 4.15704345703125 MB
# writing finished
# chunks_count 6817
# submit task
# chunk_loaded_callback
# writing started 6.62469482421875 MB
# writing finished
# chunks_count 6818
# submit task
# chunk_loaded_callback
# writing started 6.83349609375 MB
# writing finished
# chunks_count 6819
# submit task
# chunk_loaded_callback
# writing started 4.57464599609375 MB
# writing finished
# chunks_count 6819
# submit task
# chunk_loaded_callback
# writing started 7.8585205078125 MB
# writing finished
# chunks_count 6820
# submit task
# chunk_loaded_callback
# writing started 6.5677490234375 MB
# writing finished
# chunks_count 6821
# submit task
# chunk_loaded_callback
# writing started 4.3658447265625 MB
# writing finished
# chunks_count 6821
# submit task
# chunk_loaded_callback
# writing started 3.96722412109375 MB
# writing finished
# chunks_count 6821
# submit task
# chunk_loaded_callback
# writing started 4.72650146484375 MB
# writing finished
# chunks_count 6822
# submit task
# chunk_loaded_callback
# writing started 4.11907958984375 MB
# writing finished
# chunks_count 6822
# submit task
# chunk_loaded_callback
# writing started 7.3270263671875 MB
# writing finished
# chunks_count 6823
# submit task
# chunk_loaded_callback
# writing started 6.150146484375 MB
# writing finished
# chunks_count 6824
# submit task
# chunk_loaded_callback
# writing started 3.47369384765625 MB
# writing finished
# chunks_count 6824
# submit task
# chunk_loaded_callback
# writing started 7.30804443359375 MB
# writing finished
# chunks_count 6825
# submit task
# chunk_loaded_callback
# writing started 6.453857421875 MB
# writing finished
# chunks_count 6825
# submit task
# chunk_loaded_callback
# writing started 2.809326171875 MB
# writing finished
# chunks_count 6826
# submit task
# chunk_loaded_callback
# writing started 5.2010498046875 MB
# writing finished
# chunks_count 6826
# submit task
# chunk_loaded_callback
# writing started 4.08111572265625 MB
# writing finishedsubmit task
#
# chunks_count 6827
# chunk_loaded_callback
# writing started 3.96722412109375 MB
# writing finished
# chunks_count 6827
# submit task
# chunk_loaded_callback
# writing started 11.313232421875 MB
# chunk_loaded_callback
# writing finished
# chunks_count 6828
# submit task
# chunk_loaded_callback
# chunk_loaded_callback
# writing started 3.89129638671875 MB
# writing finished
# chunks_count 6828
# submit task
# writing started 5.239013671875 MB
# writing finished
# chunks_count 6829
# submit task
# writing started 4.3658447265625 MB
# writing finished
# chunks_count 6829
# submit task
# chunk_loaded_callback
# writing started 3.568603515625 MB
# writing finishedsubmit task
#
# chunks_count 6830
# chunk_loaded_callback
# writing started 3.9862060546875 MB
# writing finished
# chunks_count 6830
# submit task
# chunk_loaded_callback
# writing started 5.25799560546875 MB
# writing finished
# chunks_count 6831
# submit task
# chunk_loaded_callback
# writing started 8.29510498046875 MB
# writing finished
# chunks_count 6832
# submit task
# chunk_loaded_callback
# writing started 3.77740478515625 MB
# writing finished
# chunks_count 6832
# submit task
# chunk_loaded_callback
# writing started 4.49871826171875 MB
# writing finished
# chunks_count 6832
# submit task
# chunk_loaded_callback
# writing started 5.29595947265625 MB
# writing finished
# chunks_count 6833
# submit task
# chunk_loaded_callback
# writing started 4.19500732421875 MB
# writing finished
# chunks_count 6833
# submit task
# chunk_loaded_callback
# writing started 6.1121826171875 MB
# writing finished
# chunks_count 6834
# submit task
# chunk_loaded_callback
# writing started 4.76446533203125 MB
# writing finished
# chunks_count 6834
# submit task
# chunk_loaded_callback
# writing started 2.82830810546875 MB
# writing finished
# chunks_count 6835
# submit task
# chunk_loaded_callback
# writing started 4.34686279296875 MB
# writing finished
# chunks_count 6835
# submit task
# chunk_loaded_callback
# writing started 4.10009765625 MB
# writing finishedsubmit task
#
# chunks_count 6836
# chunk_loaded_callback
# writing started 3.720458984375 MB
# writing finished
# chunks_count 6836
# submit task
# chunk_loaded_callback
# writing started 3.9102783203125 MB
# writing finished
# chunks_count 6836
# submit task
# chunk_loaded_callback
# writing started 5.2769775390625 MB
# writing finished
# chunks_count 6837
# submit task
# chunk_loaded_callback
# writing started 5.1251220703125 MB
# writing finished
# chunks_count 6837
# submit task
# chunk_loaded_callback
# writing started 3.66351318359375 MB
# writing finishedsubmit task
#
# chunks_count 6838
# chunk_loaded_callback
# writing started 3.70147705078125 MB
# writing finished
# chunks_count 6838
# submit task
# chunk_loaded_callback
# writing started 4.40380859375 MB
# writing finished
# chunks_count 6839
# submit task
# chunk_loaded_callback
# writing started 5.5047607421875 MB
# writing finished
# chunks_count 6839
# submit task
# chunk_loaded_callback
# writing started 3.58758544921875 MB
# writing finished
# chunks_count 6839
# submit task
# chunk_loaded_callback
# writing started 5.466796875 MB
# writing finished
# chunks_count 6840
# submit task
# chunk_loaded_callback
# writing started 3.113037109375 MB
# writing finished
# chunks_count 6840
# submit task
# chunk_loaded_callback
# writing started 5.5806884765625 MB
# writing finished
# chunks_count 6841
# submit task
# chunk_loaded_callback
# writing started 3.92926025390625 MB
# writing finished
# chunks_count 6841
# submit task
# chunk_loaded_callback
# writing started 3.96722412109375 MB
# writing finished
# chunks_count 6842
# submit task
# chunk_loaded_callback
# writing started 2.8472900390625 MB
# writing finished
# chunks_count 6842
# submit task
# chunk_loaded_callback
# writing started 4.08111572265625 MB
# writing finished
# chunks_count 6842
# submit task
# chunk_loaded_callback
# writing started 3.20794677734375 MB
# writing finished
# chunks_count 6843
# submit task
# chunk_loaded_callback
# writing started 5.4288330078125 MB
# writing finished
# chunks_count 6843
# submit task
# chunk_loaded_callback
# writing started 6.43487548828125 MB
# writing finished
# chunks_count 6844
# submit task
# chunk_loaded_callback
# writing started 3.2269287109375 MB
# writing finished
# chunks_count 6844
# submit task
# chunk_loaded_callback
# writing started 4.61260986328125 MB
# writing finished
# chunks_count 6845
# submit task
# chunk_loaded_callback
# writing started 3.05609130859375 MB
# writing finished
# chunks_count 6845
# submit task
# chunk_loaded_callback
# writing started 3.872314453125 MB
# writing finished
# chunks_count 6845
# submit task
# chunk_loaded_callback
# writing started 6.9853515625 MB
# writing finished
# chunks_count 6846
# submit task
# chunk_loaded_callback
# writing started 4.024169921875 MB
# writing finished
# chunks_count 6846
# submit task
# chunk_loaded_callback
# writing started 4.08111572265625 MB
# writing finished
# chunks_count 6847
# submit task
# chunk_loaded_callback
# writing started 4.176025390625 MB
# writing finished
# chunks_count 6847
# submit task
# chunk_loaded_callback
# writing started 1.91717529296875 MB
# writing finished
# chunks_count 6847
# submit task
# chunk_loaded_callback
# writing started 3.58758544921875 MB
# writing finished
# chunks_count 6848
# submit task
# chunk_loaded_callback
# writing started 5.6566162109375 MB
# writing finished
# chunks_count 6848
# submit task
# chunk_loaded_callback
# writing started 4.61260986328125 MB
# writing finished
# chunks_count 6849
# submit task
# chunk_loaded_callback
# writing started 3.05609130859375 MB
# writing finished
# chunks_count 6849
# submit task
# chunk_loaded_callback
# writing started 2.3917236328125 MB
# writing finished
# chunks_count 6849
# submit task
# chunk_loaded_callback
# writing started 4.3658447265625 MB
# writing finished
# chunks_count 6850
# submit task
# chunk_loaded_callback
# writing started 7.30804443359375 MB
# writing finished
# chunks_count 6851
# submit task
# chunk_loaded_callback
# writing started 4.91632080078125 MB
# writing finished
# chunks_count 6851
# submit task
# chunk_loaded_callback
# writing started 5.2769775390625 MB
# writing finished
# chunks_count 6852
# submit task
# chunk_loaded_callback
# writing started 3.3028564453125 MB
# writing finished
# chunks_count 6852
# submit task
# chunk_loaded_callback
# writing started 4.4417724609375 MB
# writing finished
# chunks_count 6852
# submit task
# chunk_loaded_callback
# writing started 1.7083740234375 MB
# writing finished
# chunks_count 6853
# submit task
# chunk_loaded_callback
# writing started 6.39691162109375 MB
# writing finished
# chunks_count 6853
# submit task
# chunk_loaded_callback
# writing started 3.28387451171875 MB
# writing finished
# chunks_count 6853
# submit task
# chunk_loaded_callback
# writing started 2.67645263671875 MB
# writing finished
# chunks_count 6854
# submit task
# chunk_loaded_callback
# writing started 5.846435546875 MB
# writing finished
# chunks_count 6854
# submit task
# chunk_loaded_callback
# writing started 3.8343505859375 MB
# writing finishedsubmit task
#
# chunks_count 6855
# chunk_loaded_callback
# writing started 6.22607421875 MB
# writing finished
# chunks_count 6855
# submit task
# chunk_loaded_callback
# writing started 2.75238037109375 MB
# writing finished
# chunks_count 6856
# submit task
# chunk_loaded_callback
# writing started 5.86541748046875 MB
# writing finished
# chunks_count 6856
# submit task
# chunk_loaded_callback
# writing started 3.81536865234375 MB
# writing finishedsubmit task
#
# chunks_count 6857
# chunk_loaded_callback
# writing started 4.00518798828125 MB
# writing finished
# chunks_count 6857
# submit task
# chunk_loaded_callback
# writing started 4.19500732421875 MB
# writing finished
# chunks_count 6857
# submit task
# chunk_loaded_callback
# writing started 5.2769775390625 MB
# writing finished
# chunks_count 6858
# submit task
# chunk_loaded_callback
# writing started 5.01123046875 MB
# writing finished
# chunks_count 6858
# submit task
# chunk_loaded_callback
# writing started 3.79638671875 MB
# writing finishedsubmit task
#
# chunks_count 6859
# chunk_loaded_callback
# writing started 3.9102783203125 MB
# writing finished
# chunks_count 6859
# submit task
# chunk_loaded_callback
# writing started 6.2640380859375 MB
# writing finished
# chunks_count 6860
# submit task
# chunk_loaded_callback
# writing started 4.91632080078125 MB
# writing finished
# chunks_count 6860
# submit task
# chunk_loaded_callback
# writing started 2.94219970703125 MB
# writing finished
# chunks_count 6861
# submit task
# chunk_loaded_callback
# writing started 2.9232177734375 MB
# writing finished
# chunks_count 6861
# submit task
# chunk_loaded_callback
# writing started 4.38482666015625 MB
# writing finished
# chunks_count 6861
# submit task
# chunk_loaded_callback
# writing started 5.40985107421875 MB
# writing finished
# chunks_count 6862
# submit task
# chunk_loaded_callback
# writing started 5.2769775390625 MB
# writing finished
# chunks_count 6862
# submit task
# chunk_loaded_callback
# writing started 4.479736328125 MB
# writing finished
# chunks_count 6863
# submit task
# chunk_loaded_callback
# writing started 3.20794677734375 MB
# writing finished
# chunks_count 6863
# submit task
# chunk_loaded_callback
# writing started 5.466796875 MB
# writing finished
# chunks_count 6864
# submit task
# chunk_loaded_callback
# writing started 2.79034423828125 MB
# writing finished
# chunks_count 6864
# submit task
# chunk_loaded_callback
# writing started 3.51165771484375 MB
# writing finished
# chunks_count 6864
# submit task
# chunk_loaded_callback
# writing started 6.453857421875 MB
# writing finished
# chunks_count 6865
# submit task
# chunk_loaded_callback
# writing started 4.2899169921875 MB
# writing finished
# chunks_count 6865
# submit task
# chunk_loaded_callback
# writing started 4.10009765625 MB
# writing finished
# chunks_count 6866
# submit task
# chunk_loaded_callback
# writing started 4.5177001953125 MB
# writing finished
# chunks_count 6866
# submit task
# chunk_loaded_callback
# writing started 10.19329833984375 MB
# writing finished
# chunks_count 6867
# submit task
# chunk_loaded_callback
# writing started 5.18206787109375 MB
# writing finished
# chunks_count 6868
# submit task
# chunk_loaded_callback
# writing started 4.9732666015625 MB
# writing finished
# chunks_count 6868
# submit task
# chunk_loaded_callback
# writing started 4.08111572265625 MB
# writing finished
# chunks_count 6869
# submit task
# chunk_loaded_callback
# writing started 4.2139892578125 MB
# writing finished
# chunks_count 6869
# submit task
# chunk_loaded_callback
# writing started 4.479736328125 MB
# writing finished
# chunks_count 6870
# submit task
# chunk_loaded_callback
# writing started 3.49267578125 MB
# writing finished
# chunks_count 6870
# submit task
# chunk_loaded_callback
# writing started 3.16998291015625 MB
# writing finished
# chunks_count 6870
# submit task
# chunk_loaded_callback
# writing started 8.82659912109375 MB
# writing finished
# chunks_count 6871
# submit task
# chunk_loaded_callback
# writing started 6.5677490234375 MB
# writing finished
# chunks_count 6872
# submit task
# chunk_loaded_callback
# writing started 4.19500732421875 MB
# writing finished
# chunks_count 6872
# submit task
# chunk_loaded_callback
# writing started 4.08111572265625 MB
# writing finished
# chunks_count 6873
# submit task
# chunk_loaded_callback
# writing started 3.92926025390625 MB
# writing finished
# chunks_count 6873
# submit task
# chunk_loaded_callback
# writing started 5.846435546875 MB
# writing finished
# chunks_count 6874
# submit task
# chunk_loaded_callback
# writing started 4.46075439453125 MB
# writing finished
# chunks_count 6874
# submit task
# chunk_loaded_callback
# writing started 4.327880859375 MB
# writing finished
# chunks_count 6875
# submit task
# chunk_loaded_callback
# writing started 5.8084716796875 MB
# writing finished
# chunks_count 6875
# submit task
# chunk_loaded_callback
# writing started 4.479736328125 MB
# writing finished
# chunks_count 6876
# submit task
# chunk_loaded_callback
# writing started 4.34686279296875 MB
# writing finished
# chunks_count 6876
# submit task
# chunk_loaded_callback
# writing started 5.18206787109375 MB
# writing finished
# chunks_count 6877
# submit task
# chunk_loaded_callback
# writing started 6.3779296875 MB
# writing finished
# chunks_count 6877
# submit task
# chunk_loaded_callback
# writing started 2.88525390625 MB
# writing finished
# chunks_count 6877
# submit task
# chunk_loaded_callback
# writing started 4.0621337890625 MB
# writing finished
# chunks_count 6878
# submit task
# chunk_loaded_callback
# writing started 4.176025390625 MB
# writing finished
# chunks_count 6878
# submit task
# chunk_loaded_callback
# writing started 4.87835693359375 MB
# writing finished
# chunks_count 6879
# submit task
# chunk_loaded_callback
# writing started 2.809326171875 MB
# writing finished
# chunks_count 6879
# submit task
# chunk_loaded_callback
# writing started 2.48663330078125 MB
# writing finished
# chunks_count 6879
# submit task
# chunk_loaded_callback
# writing started 5.31494140625 MB
# writing finished
# chunks_count 6880
# submit task
# chunk_loaded_callback
# writing started 7.820556640625 MB
# writing finished
# chunks_count 6881
# submit task
# chunk_loaded_callback
# writing started 5.3529052734375 MB
# writing finished
# chunks_count 6881
# submit task
# chunk_loaded_callback
# writing started 2.6195068359375 MB
# writing finished
# chunks_count 6881
# submit task
# chunk_loaded_callback
# writing started 2.37274169921875 MB
# writing finished
# chunks_count 6882
# submit task
# chunk_loaded_callback
# writing started 2.88525390625 MB
# writing finished
# chunks_count 6882
# submit task
# chunk_loaded_callback
# writing started 2.71441650390625 MB
# writing finished
# chunks_count 6882
# submit task
# chunk_loaded_callback
# writing started 5.82745361328125 MB
# writing finished
# chunks_count 6883
# submit task
# chunk_loaded_callback
# writing started 4.08111572265625 MB
# writing finished
# chunks_count 6883
# submit task
# chunk_loaded_callback
# writing started 3.720458984375 MB
# writing finished
# chunks_count 6884
# submit task
# chunk_loaded_callback
# writing started 3.9482421875 MB
# writing finished
# chunks_count 6884
# submit task
# chunk_loaded_callback
# writing started 2.201904296875 MB
# writing finished
# chunks_count 6884
# submit task
# chunk_loaded_callback
# writing started 4.19500732421875 MB
# writing finishedsubmit task
#
# chunks_count 6885
# chunk_loaded_callback
# writing started 2.22088623046875 MB
# writing finished
# chunks_count 6885
# submit task
# DONE
# chunk_loaded_callback
# writing started 2.79034423828125 MB
# writing finished
# chunks_count 6885
# chunk_loaded_callback
# writing started 2.98016357421875 MB
# writing finished
# chunks_count 6885
# chunk_loaded_callback
# writing started 0.70233154296875 MB
# writing finished
# chunks_count 6885
# Heartbeat failed. Closing connection

# %%
from dataset_lib import get_lenta_records, get_writers_multi_stream

k = 10
for i in get_writers_multi_stream():
    print(i)
    k -= 1
    if k <= 0:
        break

# %%
class Kek:
    def __init__(self, a):
        self.a = a
    
    def read(self, cnt=-1): 
        print(cnt)
        return self.a.read(cnt)
    def readline(self): raise Exception("no realization")
    def readable(self): return True

    def write(self, buf):
        print(len(buf))

import io
import dill

a = Kek(io.BytesIO())

dill.dump(["kek"] * 1000, a)

# Reset the position of the BytesIO object to the beginning
a.a.seek(0)

# Pass the BytesIO object directly to the Kek class
a.a.read()
